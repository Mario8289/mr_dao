# %%
from iexfinance.stocks import Stock, get_historical_data

# %%
token = "sk_ff2092d22367451ca4cfed51f0d6cb85"

# %%
aapl = Stock("APPL", token=token)

# %%
cash_flow = aapl.get_cash_flow(period='quarter', last=1)

# %%
cash_flow
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
class A:
    aa = 'hi'
    
    def __init__(self):
        pass
    
    def h(self):
        print(aa)

# %%
a = A()

# %%
a.h()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-c42541cb4fa5> in <module>
# ----> 1 a.h()
#
# <ipython-input-26-b8a2fd6d6e09> in h(self)
#       6
#       7     def h(self):
# ----> 8         print(aa)
#
# NameError: name 'aa' is not defined

# %%
# !pipenv install yahoo_fin
# Out:
# Installing yahoo_fin…
# Adding yahoo_fin to Pipfile's [packages]…
# ✔ Installation Succeeded
# Pipfile.lock (bf86f4) out of date, updating to (91645a)…
# Locking [dev-packages] dependencies…
# Locking [packages] dependencies…
# ✔ Success!
# Updated Pipfile.lock (bf86f4)!
# Installing dependencies from Pipfile.lock (bf86f4)…
#   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 68/68 — 00:00:10mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm

# %%
# !pipenv install lxml
# Out:
# Installing lxml…
# Adding lxml to Pipfile's [packages]…
# ✔ Installation Succeeded
# Pipfile.lock (5791d6) out of date, updating to (bf86f4)…
# Locking [dev-packages] dependencies…
# Locking [packages] dependencies…
# ✔ Success!
# Updated Pipfile.lock (5791d6)!
# Installing dependencies from Pipfile.lock (5791d6)…
#   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 69/69 — 00:00:12mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm

# %%
from yahoo_fin.stock_info import *

a = get_analysts_info("AAPL")

# %%
c = get_cash_flow("BOO")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-8aebc345175c> in <module>
# ----> 1 c = get_cash_flow("BOO")
#
# ~/.local/share/virtualenvs/invest-svoXdBed/lib/python3.7/site-packages/yahoo_fin/stock_info.py in get_cash_flow(ticker, yearly)
#     359
#     360     if yearly:
# --> 361         temp = json_info["cashflowStatementHistory"]["cashflowStatements"]
#     362     else:
#     363         temp = json_info["cashflowStatementHistoryQuarterly"]["cashflowStatements"]
#
# KeyError: 'cashflowStatementHistory'

# %%
c

# %%
{"total":5,
 "offset":0,
 "results":[
     {"isTrailing12Months":false,
      "sections":[
          {"sectionHeader":"&NBSP;","lineItems":[
              {"label":"CASH AT BEGINNING OF PERIOD","value":5595000000},
              {"label":"CASH AT END OF PERIOD","value":6510000000},
              {"label":"EFFECT OF EXCHANGE RATE CHANGES","value":-67000000},
              {"label":"NET CHANGE IN CASH","value":915000000}],"subsections":[
              {"sectionHeader":"CASH FLOWS FROM FINANCING ACTIVITIES","lineItems":[
                  {"label":"COMMON STOCK ISSUED","value":668000000},
                  {"label":"COMMON STOCK REPURCHASED","value":-15969000000},
                  {"label":"DEBT ISSUED","value":13884000000},
                  {"label":"DEBT REPAYMENT","value":-2796000000},
                  {"label":"DIVIDEND PAID","value":-11006000000},
                  {"label":"DIVIDEND PAYABLE","value":null},
                  {"label":"EXCESS TAX BENEFIT FROM STOCK BASED COMPENSATION","value":null},
                  {"label":"OTHER FINANCING ACTIVITIES","value":6826000000},
                  {"label":"PREFERRED STOCK ISSUED","value":null},
                  {"label":"PREFERRED STOCK REPAID","value":null},
                  {"label":"WARRANT ISSUED","value":null}],
               "subsections":[],"summaryLineItem":
               {"label":"NET CASH PROVIDED BY (USED FOR) FINANCING ACTIVITIES","value":-8393000000}},
              {"sectionHeader":"CASH FLOWS FROM INVESTING ACTIVITIES",
               "lineItems":[{"label":"ACQUISITIONS, NET","value":-1393000000},
                            {"label":"INVESTMENTS IN PROPERTY, PLANT, AND EQUIPMENT","value":-8343000000},
                            {"label":"INVESTMENTS IN TECHNOLOGIES","value":null},
                            {"label":"OTHER INVESTING ACTIVITIES","value":203000000},
                            {"label":"PROPERTY, PLANT, AND EQUIPMENT REDUCTIONS","value":null},
                            {"label":"PURCHASES OF INTANGIBLES","value":null},
                            {"label":"PURCHASES OF INVESTMENTS","value":-129758000000},
                            {"label":"SALES OF INTANGIBLES","value":null},
                            {"label":"SALES OF TECHNOLOGIES","value":null},
                            {"label":"SALES/MATURITIES OF INVESTMENTS","value":115341000000}
                           ],
               "subsections":[],
               "summaryLineItem":
               {"label":"NET CASH USED FOR INVESTING ACTIVITIES","value":-23950000000}},
              {"sectionHeader":"CASH FLOWS FROM OPERATING ACTIVITIES",
               "lineItems":[
                   {"label":"(GAIN) LOSS FROM DISCONTINUED OPERATIONS","value":null},
                   {"label":"ACCOUNTS PAYABLE","value":88000000},
                   {"label":"ACCOUNTS RECEIVABLE","value":562000000},
                   {"label":"ACCRUED LIABILITIES","value":null},
                   {"label":"AMORTIZATION OF DEBT DISCOUNT/PREMIUM AND ISSUANCE COSTS","value":null},
                   {"label":"CHANGE IN WORKING CAPITAL","value":908000000},
                   {"label":"CUMULATIVE EFFECT OF ACCOUNTING CHANGE","value":null},
                   {"label":"DEFERRED INCOME TAXES","value":2181000000},
                   {"label":"DEPRECIATION & AMORTIZATION","value":6622000000},
                   {"label":"EXTRAORDINARY ITEMS","value":null},
                   {"label":"INCOME TAXES PAYABLE","value":null},
                   {"label":"INTEREST PAYABLE","value":null},
                   {"label":"INVENTORY","value":600000000},
                   {"label":"INVESTMENT/ASSET IMPAIRMENT CHARGES","value":630000000},
                   {"label":"INVESTMENTS LOSSES (GAINS)","value":-223000000},
                   {"label":"NET INCOME","value":20539000000},
                   {"label":"OTHER NON-CASH ITEMS","value":null},
                   {"label":"OTHER WORKING CAPITAL","value":-342000000},
                   {"label":"PREPAID EXPENSES","value":null},
                   {"label":"STOCK BASED COMPENSATION","value":2668000000}],"subsections":[],"summaryLineItem":{"label":"NET CASH PROVIDED BY OPERATING ACTIVITIES","value":33325000000}},{"sectionHeader":"FREE CASH FLOW","lineItems":[{"label":"CAPITAL EXPENDITURE","value":-8343000000},{"label":"FREE CASH FLOW","value":24982000000},{"label":"OPERATING CASH FLOW","value":33325000000}],"subsections":[],"summaryLineItem":null}],"summaryLineItem":null}],"periodEndDate":"2016-06-30"},{"isTrailing12Months":false,"sections":[{"sectionHeader":"&NBSP;","lineItems":[{"label":"CASH AT BEGINNING OF PERIOD","value":6510000000},{"label":"CASH AT END OF PERIOD","value":7663000000},{"label":"EFFECT OF EXCHANGE RATE CHANGES","value":19000000},{"label":"NET CHANGE IN CASH","value":1153000000}],"subsections":[{"sectionHeader":"CASH FLOWS FROM FINANCING ACTIVITIES","lineItems":[{"label":"COMMON STOCK ISSUED","value":772000000},{"label":"COMMON STOCK REPURCHASED","value":-11788000000},{"label":"DEBT ISSUED","value":44344000000},{"label":"DEBT REPAYMENT","value":-7922000000},{"label":"DIVIDEND PAID","value":-11845000000},{"label":"DIVIDEND PAYABLE","value":null},{"label":"EXCESS TAX BENEFIT FROM STOCK BASED COMPENSATION","value":null},{"label":"OTHER FINANCING ACTIVITIES","value":-5153000000},{"label":"PREFERRED STOCK ISSUED","value":null},{"label":"PREFERRED STOCK REPAID","value":null},{"label":"WARRANT ISSUED","value":null}],"subsections":[],"summaryLineItem":{"label":"NET CASH PROVIDED BY (USED FOR) FINANCING ACTIVITIES","value":8408000000}},{"sectionHeader":"CASH FLOWS FROM INVESTING ACTIVITIES","lineItems":[{"label":"ACQUISITIONS, NET","value":-25944000000},{"label":"INVESTMENTS IN PROPERTY, PLANT, AND EQUIPMENT","value":-8129000000},{"label":"INVESTMENTS IN TECHNOLOGIES","value":null},{"label":"OTHER INVESTING ACTIVITIES","value":-197000000},{"label":"PROPERTY, PLANT, AND EQUIPMENT REDUCTIONS","value":null},{"label":"PURCHASES OF INTANGIBLES","value":null},{"label":"PURCHASES OF INVESTMENTS","value":-176905000000},{"label":"SALES OF INTANGIBLES","value":null},{"label":"SALES OF TECHNOLOGIES","value":null},{"label":"SALES/MATURITIES OF INVESTMENTS","value":164394000000}],"subsections":[],"summaryLineItem":{"label":"NET CASH USED FOR INVESTING ACTIVITIES","value":-46781000000}},{"sectionHeader":"CASH FLOWS FROM OPERATING ACTIVITIES","lineItems":[{"label":"(GAIN) LOSS FROM DISCONTINUED OPERATIONS","value":null},{"label":"ACCOUNTS PAYABLE","value":81000000},{"label":"ACCOUNTS RECEIVABLE","value":-1216000000},{"label":"ACCRUED LIABILITIES","value":null},{"label":"AMORTIZATION OF DEBT DISCOUNT/PREMIUM AND ISSUANCE COSTS","value":null},{"label":"CHANGE IN WORKING CAPITAL","value":3084000000},{"label":"CUMULATIVE EFFECT OF ACCOUNTING CHANGE","value":null},{"label":"DEFERRED INCOME TAXES","value":963000000},{"label":"DEPRECIATION & AMORTIZATION","value":8778000000},{"label":"EXTRAORDINARY ITEMS","value":null},{"label":"INCOME TAXES PAYABLE","value":null},{"label":"INTEREST PAYABLE","value":null},{"label":"INVENTORY","value":50000000},{"label":"INVESTMENT/ASSET IMPAIRMENT CHARGES","value":null},{"label":"INVESTMENTS LOSSES (GAINS)","value":-2073000000},{"label":"NET INCOME","value":25489000000},{"label":"OTHER NON-CASH ITEMS","value":null},{"label":"OTHER WORKING CAPITAL","value":4169000000},{"label":"PREPAID EXPENSES","value":null},{"label":"STOCK BASED COMPENSATION","value":3266000000}],"subsections":[],"summaryLineItem":{"label":"NET CASH PROVIDED BY OPERATING ACTIVITIES","value":39507000000}},{"sectionHeader":"FREE CASH FLOW","lineItems":[{"label":"CAPITAL EXPENDITURE","value":-8129000000},{"label":"FREE CASH FLOW","value":31378000000},{"label":"OPERATING CASH FLOW","value":39507000000}],"subsections":[],"summaryLineItem":null}],"summaryLineItem":null}],"periodEndDate":"2017-06-30"},{"isTrailing12Months":false,"sections":[{"sectionHeader":"&NBSP;","lineItems":[{"label":"CASH AT BEGINNING OF PERIOD","value":7663000000},{"label":"CASH AT END OF PERIOD","value":11946000000},{"label":"EFFECT OF EXCHANGE RATE CHANGES","value":50000000},{"label":"NET CHANGE IN CASH","value":4283000000}],"subsections":[{"sectionHeader":"CASH FLOWS FROM FINANCING ACTIVITIES","lineItems":[{"label":"COMMON STOCK ISSUED","value":1002000000},{"label":"COMMON STOCK REPURCHASED","value":-10721000000},{"label":"DEBT ISSUED","value":7183000000},{"label":"DEBT REPAYMENT","value":-10060000000},{"label":"DIVIDEND PAID","value":-12699000000},{"label":"DIVIDEND PAYABLE","value":null},{"label":"EXCESS TAX BENEFIT FROM STOCK BASED COMPENSATION","value":null},{"label":"OTHER FINANCING ACTIVITIES","value":-8295000000},{"label":"PREFERRED STOCK ISSUED","value":null},{"label":"PREFERRED STOCK REPAID","value":null},{"label":"WARRANT ISSUED","value":null}],"subsections":[],"summaryLineItem":{"label":"NET CASH PROVIDED BY (USED FOR) FINANCING ACTIVITIES","value":-33590000000}},{"sectionHeader":"CASH FLOWS FROM INVESTING ACTIVITIES","lineItems":[{"label":"ACQUISITIONS, NET","value":-888000000},{"label":"INVESTMENTS IN PROPERTY, PLANT, AND EQUIPMENT","value":-11632000000},{"label":"INVESTMENTS IN TECHNOLOGIES","value":null},{"label":"OTHER INVESTING ACTIVITIES","value":-98000000},{"label":"PROPERTY, PLANT, AND EQUIPMENT REDUCTIONS","value":null},{"label":"PURCHASES OF INTANGIBLES","value":null},{"label":"PURCHASES OF INVESTMENTS","value":-137380000000},{"label":"SALES OF INTANGIBLES","value":null},{"label":"SALES OF TECHNOLOGIES","value":null},{"label":"SALES/MATURITIES OF INVESTMENTS","value":143937000000}],"subsections":[],"summaryLineItem":{"label":"NET CASH USED FOR INVESTING ACTIVITIES","value":-6061000000}},{"sectionHeader":"CASH FLOWS FROM OPERATING ACTIVITIES","lineItems":[{"label":"(GAIN) LOSS FROM DISCONTINUED OPERATIONS","value":null},{"label":"ACCOUNTS PAYABLE","value":1148000000},{"label":"ACCOUNTS RECEIVABLE","value":-3862000000},{"label":"ACCRUED LIABILITIES","value":null},{"label":"AMORTIZATION OF DEBT DISCOUNT/PREMIUM AND ISSUANCE COSTS","value":null},{"label":"CHANGE IN WORKING CAPITAL","value":2284000000},{"label":"CUMULATIVE EFFECT OF ACCOUNTING CHANGE","value":null},{"label":"DEFERRED INCOME TAXES","value":13040000000},{"label":"DEPRECIATION & AMORTIZATION","value":10261000000},{"label":"EXTRAORDINARY ITEMS","value":null},{"label":"INCOME TAXES PAYABLE","value":null},{"label":"INTEREST PAYABLE","value":null},{"label":"INVENTORY","value":-465000000},{"label":"INVESTMENT/ASSET IMPAIRMENT CHARGES","value":null},{"label":"INVESTMENTS LOSSES (GAINS)","value":-2212000000},{"label":"NET INCOME","value":16571000000},{"label":"OTHER NON-CASH ITEMS","value":null},{"label":"OTHER WORKING CAPITAL","value":5463000000},{"label":"PREPAID EXPENSES","value":null},{"label":"STOCK BASED COMPENSATION","value":3940000000}],"subsections":[],"summaryLineItem":{"label":"NET CASH PROVIDED BY OPERATING ACTIVITIES","value":43884000000}},{"sectionHeader":"FREE CASH FLOW","lineItems":[{"label":"CAPITAL EXPENDITURE","value":-11632000000},{"label":"FREE CASH FLOW","value":32252000000},{"label":"OPERATING CASH FLOW","value":43884000000}],"subsections":[],"summaryLineItem":null}],"summaryLineItem":null}],"periodEndDate":"2018-06-30"},{"isTrailing12Months":false,"sections":[{"sectionHeader":"&NBSP;","lineItems":[{"label":"CASH AT BEGINNING OF PERIOD","value":11946000000},{"label":"CASH AT END OF PERIOD","value":11356000000},{"label":"EFFECT OF EXCHANGE RATE CHANGES","value":-115000000},{"label":"NET CHANGE IN CASH","value":-590000000}],"subsections":[{"sectionHeader":"CASH FLOWS FROM FINANCING ACTIVITIES","lineItems":[{"label":"COMMON STOCK ISSUED","value":1142000000},{"label":"COMMON STOCK REPURCHASED","value":-19543000000},{"label":"DEBT ISSUED","value":null},{"label":"DEBT REPAYMENT","value":-4000000000},{"label":"DIVIDEND PAID","value":-13811000000},{"label":"DIVIDEND PAYABLE","value":null},{"label":"EXCESS TAX BENEFIT FROM STOCK BASED COMPENSATION","value":null},{"label":"OTHER FINANCING ACTIVITIES","value":-675000000},{"label":"PREFERRED STOCK ISSUED","value":null},{"label":"PREFERRED STOCK REPAID","value":null},{"label":"WARRANT ISSUED","value":null}],"subsections":[],"summaryLineItem":{"label":"NET CASH PROVIDED BY (USED FOR) FINANCING ACTIVITIES","value":-36887000000}},{"sectionHeader":"CASH FLOWS FROM INVESTING ACTIVITIES","lineItems":[{"label":"ACQUISITIONS, NET","value":-2388000000},{"label":"INVESTMENTS IN PROPERTY, PLANT, AND EQUIPMENT","value":-13925000000},{"label":"INVESTMENTS IN TECHNOLOGIES","value":null},{"label":"OTHER INVESTING ACTIVITIES","value":null},{"label":"PROPERTY, PLANT, AND EQUIPMENT REDUCTIONS","value":null},{"label":"PURCHASES OF INTANGIBLES","value":null},{"label":"PURCHASES OF INVESTMENTS","value":-57697000000},{"label":"SALES OF INTANGIBLES","value":null},{"label":"SALES OF TECHNOLOGIES","value":null},{"label":"SALES/MATURITIES OF INVESTMENTS","value":58237000000}],"subsections":[],"summaryLineItem":{"label":"NET CASH USED FOR INVESTING ACTIVITIES","value":-15773000000}},{"sectionHeader":"CASH FLOWS FROM OPERATING ACTIVITIES","lineItems":[{"label":"(GAIN) LOSS FROM DISCONTINUED OPERATIONS","value":null},{"label":"ACCOUNTS PAYABLE","value":232000000},{"label":"ACCOUNTS RECEIVABLE","value":-2812000000},{"label":"ACCRUED LIABILITIES","value":null},{"label":"AMORTIZATION OF DEBT DISCOUNT/PREMIUM AND ISSUANCE COSTS","value":null},{"label":"CHANGE IN WORKING CAPITAL","value":937000000},{"label":"CUMULATIVE EFFECT OF ACCOUNTING CHANGE","value":null},{"label":"DEFERRED INCOME TAXES","value":-3534000000},{"label":"DEPRECIATION & AMORTIZATION","value":11682000000},{"label":"EXTRAORDINARY ITEMS","value":null},{"label":"INCOME TAXES PAYABLE","value":null},{"label":"INTEREST PAYABLE","value":null},{"label":"INVENTORY","value":597000000},{"label":"INVESTMENT/ASSET IMPAIRMENT CHARGES","value":null},{"label":"INVESTMENTS LOSSES (GAINS)","value":-792000000},{"label":"NET INCOME","value":39240000000},{"label":"OTHER NON-CASH ITEMS","value":null},{"label":"OTHER WORKING CAPITAL","value":2920000000},{"label":"PREPAID EXPENSES","value":null},{"label":"STOCK BASED COMPENSATION","value":4652000000}],"subsections":[],"summaryLineItem":{"label":"NET CASH PROVIDED BY OPERATING ACTIVITIES","value":52185000000}},{"sectionHeader":"FREE CASH FLOW","lineItems":[{"label":"CAPITAL EXPENDITURE","value":-13925000000},{"label":"FREE CASH FLOW","value":38260000000},{"label":"OPERATING CASH FLOW","value":52185000000}],"subsections":[],"summaryLineItem":null}],"summaryLineItem":null}],"periodEndDate":"2019-06-30"},{"isTrailing12Months":false,"sections":[{"sectionHeader":"&NBSP;","lineItems":[{"label":"CASH AT BEGINNING OF PERIOD","value":11356000000},{"label":"CASH AT END OF PERIOD","value":13576000000},{"label":"EFFECT OF EXCHANGE RATE CHANGES","value":-201000000},{"label":"NET CHANGE IN CASH","value":2220000000}],"subsections":[{"sectionHeader":"CASH FLOWS FROM FINANCING ACTIVITIES","lineItems":[{"label":"COMMON STOCK ISSUED","value":1343000000},{"label":"COMMON STOCK REPURCHASED","value":-22968000000},{"label":"DEBT ISSUED","value":null},{"label":"DEBT REPAYMENT","value":-5518000000},{"label":"DIVIDEND PAID","value":-15137000000},{"label":"DIVIDEND PAYABLE","value":null},{"label":"EXCESS TAX BENEFIT FROM STOCK BASED COMPENSATION","value":null},{"label":"OTHER FINANCING ACTIVITIES","value":-3751000000},{"label":"PREFERRED STOCK ISSUED","value":null},{"label":"PREFERRED STOCK REPAID","value":null},{"label":"WARRANT ISSUED","value":null}],"subsections":[],"summaryLineItem":{"label":"NET CASH PROVIDED BY (USED FOR) FINANCING ACTIVITIES","value":-46031000000}},{"sectionHeader":"CASH FLOWS FROM INVESTING ACTIVITIES","lineItems":[{"label":"ACQUISITIONS, NET","value":-2521000000},{"label":"INVESTMENTS IN PROPERTY, PLANT, AND EQUIPMENT","value":-15441000000},{"label":"INVESTMENTS IN TECHNOLOGIES","value":null},{"label":"OTHER INVESTING ACTIVITIES","value":-1241000000},{"label":"PROPERTY, PLANT, AND EQUIPMENT REDUCTIONS","value":null},{"label":"PURCHASES OF INTANGIBLES","value":null},{"label":"PURCHASES OF INVESTMENTS","value":-77190000000},{"label":"SALES OF INTANGIBLES","value":null},{"label":"SALES OF TECHNOLOGIES","value":null},{"label":"SALES/MATURITIES OF INVESTMENTS","value":84170000000}],"subsections":[],"summaryLineItem":{"label":"NET CASH USED FOR INVESTING ACTIVITIES","value":-12223000000}},{"sectionHeader":"CASH FLOWS FROM OPERATING ACTIVITIES","lineItems":[{"label":"(GAIN) LOSS FROM DISCONTINUED OPERATIONS","value":null},{"label":"ACCOUNTS PAYABLE","value":3018000000},{"label":"ACCOUNTS RECEIVABLE","value":-2577000000},{"label":"ACCRUED LIABILITIES","value":null},{"label":"AMORTIZATION OF DEBT DISCOUNT/PREMIUM AND ISSUANCE COSTS","value":null},{"label":"CHANGE IN WORKING CAPITAL","value":2148000000},{"label":"CUMULATIVE EFFECT OF ACCOUNTING CHANGE","value":null},{"label":"DEFERRED INCOME TAXES","value":-3620000000},{"label":"DEPRECIATION & AMORTIZATION","value":12796000000},{"label":"EXTRAORDINARY ITEMS","value":null},{"label":"INCOME TAXES PAYABLE","value":null},{"label":"INTEREST PAYABLE","value":null},{"label":"INVENTORY","value":168000000},{"label":"INVESTMENT/ASSET IMPAIRMENT CHARGES","value":null},{"label":"INVESTMENTS LOSSES (GAINS)","value":-219000000},{"label":"NET INCOME","value":44281000000},{"label":"OTHER NON-CASH ITEMS","value":null},{"label":"OTHER WORKING CAPITAL","value":1539000000},{"label":"PREPAID EXPENSES","value":null},{"label":"STOCK BASED COMPENSATION","value":5289000000}],"subsections":[],"summaryLineItem":{"label":"NET CASH PROVIDED BY OPERATING ACTIVITIES","value":60675000000}},{"sectionHeader":"FREE CASH FLOW","lineItems":[{"label":"CAPITAL EXPENDITURE","value":-15441000000},{"label":"FREE CASH FLOW","value":45234000000},{"label":"OPERATING CASH FLOW","value":60675000000}],"subsections":[],"summaryLineItem":null}],"summaryLineItem":null}],"periodEndDate":"2020-06-30"}],"responseStatus":null}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e50d96d8c676> in <module>
#       2  "offset":0,
#       3  "results":[
# ----> 4      {"isTrailing12Months":false,
#       5       "sections":[
#       6           {"sectionHeader":"&NBSP;","lineItems":[
#
# NameError: name 'false' is not defined

# %%
cashflow = {'symbol': 'AAPL', 'cashflow': [{'capitalExpenditures': -7309000000, 'cashChange': -2082000000, 'cashFlow': 80674000000, 'cashFlowFinancing': -86820000000, 'changesInInventories': 83000000, 'changesInReceivables': 5370000000, 'currency': 'USD', 'depreciation': 11056000000, 'dividendsPaid': None, 'exchangeRateEffect': None, 'filingType': '10-K', 'fiscalDate': '2020-09-26', 'fiscalQuarter': 4, 'fiscalYear': 2020, 'investingActivityOther': None, 'investments': None, 'netBorrowings': 10229000000, 'netIncome': 12673000000, 'otherFinancingCashFlows': None, 'reportDate': '2020-10-30', 'symbol': 'AAPL', 'totalInvestingCashFlows': -4289000000, 'id': 'CASH_FLOW', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1601078400000, 'updated': 1608330864000}, {'capitalExpenditures': -5525000000, 'cashChange': -1026000000, 'cashFlow': 60098000000, 'cashFlowFinancing': -65463000000, 'changesInInventories': 644000000, 'changesInReceivables': 1398000000, 'currency': 'USD', 'depreciation': 8354000000, 'dividendsPaid': None, 'exchangeRateEffect': None, 'filingType': '10-Q', 'fiscalDate': '2020-06-27', 'fiscalQuarter': 3, 'fiscalYear': 2020, 'investingActivityOther': None, 'investments': None, 'netBorrowings': 8711000000, 'netIncome': 11253000000, 'otherFinancingCashFlows': None, 'reportDate': '2020-07-31', 'symbol': 'AAPL', 'totalInvestingCashFlows': -9820000000, 'id': 'CASH_FLOW', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1593216000000, 'updated': 1608330864000}, {'capitalExpenditures': -3960000000, 'cashChange': -13111000000, 'cashFlow': 43827000000, 'cashFlowFinancing': -46347000000, 'changesInInventories': -763000000, 'changesInReceivables': -9269000000, 'currency': 'USD', 'depreciation': 5602000000, 'dividendsPaid': None, 'exchangeRateEffect': None, 'filingType': '10-Q', 'fiscalDate': '2020-03-28', 'fiscalQuarter': 2, 'fiscalYear': 2020, 'investingActivityOther': None, 'investments': None, 'netBorrowings': 842000000, 'netIncome': 11249000000, 'otherFinancingCashFlows': None, 'reportDate': '2020-05-01', 'symbol': 'AAPL', 'totalInvestingCashFlows': -4655000000, 'id': 'CASH_FLOW', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1585353600000, 'updated': 1608330864000}, {'capitalExpenditures': -2107000000, 'cashChange': 6605000000, 'cashFlow': 30516000000, 'cashFlowFinancing': -25407000000, 'changesInInventories': -9000000, 'changesInReceivables': -5858000000, 'currency': 'USD', 'depreciation': 2816000000, 'dividendsPaid': None, 'exchangeRateEffect': None, 'filingType': '10-Q', 'fiscalDate': '2019-12-28', 'fiscalQuarter': 1, 'fiscalYear': 2020, 'investingActivityOther': None, 'investments': None, 'netBorrowings': -10896000000, 'netIncome': 22236000000, 'otherFinancingCashFlows': None, 'reportDate': '2020-01-29', 'symbol': 'AAPL', 'totalInvestingCashFlows': -13668000000, 'id': 'CASH_FLOW', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 
 'investingActivityOther': None, 'investments': None, 'netBorrowings': 31142000000, 'netIncome': 11519000000, 'otherFinancingCashFlows': None, 'reportDate': '2018-08-01', 'symbol': 'AAPL', 'totalInvestingCashFlows': 12049500000, 'id': 'CASH_FLOW', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1530316800000, 'updated': 1608330864000}, {'capitalExpenditures': -6656500000, 'cashChange': 10787000000, 'cashFlow': 38717000000, 'cashFlowFinancing': -43938000000, 'changesInInventories': 3241000000, 'changesInReceivables': -28491000000, 'currency': 'USD', 'depreciation': 5451500000, 'dividendsPaid': None, 'exchangeRateEffect': None, 'filingType': '10-Q', 'fiscalDate': '2018-03-31', 'fiscalQuarter': 2, 'fiscalYear': 2018, 'investingActivityOther': None, 'investments': None, 'netBorrowings': 21857000000, 'netIncome': 13822000000, 'otherFinancingCashFlows': None, 'reportDate': '2018-05-02', 'symbol': 'AAPL', 'totalInvestingCashFlows': 8033000000, 'id': 'CASH_FLOW', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1522454400000, 'updated': 1608330864000}, {'capitalExpenditures': -3328250000, 'cashChange': 2972000000, 'cashFlow': 19358500000, 'cashFlowFinancing': -21969000000, 'changesInInventories': -434000000, 'changesInReceivables': 15226000000, 'currency': 'USD', 'depreciation': 2725750000, 'dividendsPaid': None, 'exchangeRateEffect': None, 'filingType': '10-Q', 'fiscalDate': '2017-12-30', 'fiscalQuarter': 1, 'fiscalYear': 2018, 'investingActivityOther': None, 'investments': None, 'netBorrowings': 33910000000, 'netIncome': 20065000000, 'otherFinancingCashFlows': None, 'reportDate': '2018-02-02', 'symbol': 'AAPL', 'totalInvestingCashFlows': 4016500000, 'id': 'CASH_FLOW', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1514592000000, 'updated': 1608330864000}]}
advanced_fundamentals = [{'accountsPayable': 42296000000, 'accountsPayableTurnover': 1.52964819368262, 'accountsReceivable': 37445000000, 'accountsReceivableTurnover': 1.72781412738683, 'asOfDate': '2020-11-02', 'assetsCurrentCash': 90943000000, 'assetsCurrentCashRestricted': 0, 'assetsCurrentDeferredCompensation': 0, 'assetsCurrentDeferredTax': 0, 'assetsCurrentDiscontinuedOperations': 0, 'assetsCurrentInvestments': 0, 'assetsCurrentLeasesOperating': 0, 'assetsCurrentLoansNet': 0, 'assetsCurrentOther': 11264000000, 'assetsCurrentSeparateAccounts': 0, 'assetsCurrentUnadjusted': 143713000000, 'assetsFixed': 180175000000, 'assetsFixedDeferredCompensation': 0, 'assetsFixedDeferredTax': 0, 'assetsFixedDiscontinuedOperations': 0, 'assetsFixedLeasesOperating': 0, 'assetsFixedOperatingDiscontinuedOperations': 0, 'assetsFixedOperatingSubsidiaryUnconsolidated': 0, 'assetsFixedOreo': 0, 'assetsFixedOther': 42522000000, 'assetsFixedUnconsolidated': 0, 'assetsUnadjusted': 323888000000, 'capex': -7309000000, 'capexAcquisition': -1524000000, 'capexMaintenance': 0, 'cashConversionCycle': -10.3398868589446, 'cashFlowFinancing': -86820000000, 'cashFlowInvesting': -4289000000, 'cashFlowOperating': 80674000000, 'cashFlowShareRepurchase': -72358000000, 'cashLongTerm': 100887000000, 'cashOperating': 0, 'cashPaidForIncomeTaxes': 0, 'cashPaidForInterest': 0, 'cashRestricted': 0, 'chargeAfterTax': 0, 'chargeAfterTaxDiscontinuedOperations': 0, 'chargesAfterTaxOther': 0, 'cik': '0000320193', 'creditLossProvision': 0, 'dataGenerationDate': '2020-11-
ndInterestMinorityTotal': 153157000000, 'liabilitiesNonCurrentDebt': 98667000000, 'liabilitiesNonCurrentDeferredCompensation': 0, 'liabilitiesNonCurrentDeferredTax': 0, 'liabilitiesNonCurrentDiscontinuedOperations': 0, 'liabilitiesNonCurrentLeasesOperating': 0, 'liabilitiesNonCurrentLongTerm': 54490000000, 'liabilitiesNonCurrentOperatingDiscontinuedOperations': 0, 'liabilitiesNonCurrentOther': 54490000000, 'nibclDeferredCompensation': 0, 'nibclDeferredTax': 0, 'nibclDiscontinuedOperations': 0, 'nibclLeasesOperating': 0, 'nibclOther': 42684000000, 'nibclRestructuring': 0, 'nibclRevenueDeferred': 6643000000, 'nibclRevenueDeferredTurnover': 9.73927442420593, 'nibclSeparateAccounts': 0, 'oci': -406000000, 'periodEndDate': '2020-09-26', 'ppAndENet': 36766000000, 'pricePerEarnings': 152.889017179831, 'pricePerEarningsPerRevenueYoyDeltaPercent': 148.799584501465, 'profitGross': 24689000000, 'profitGrossPerRevenue': 0.38160375900337, 'reportDate': '2020-10-30', 'researchAndDevelopmentExpense': 4978000000, 'reserves': 0, 'reservesInventory': 0, 'reservesLifo': 0, 'reservesLoanLoss': 0, 'revenue': 64698000000, 'revenueCostOther': 40009000000, 'revenueIncomeInterest': 0, 'revenueOther': 64698000000, 'revenueSubsidiaryUnconsolidated': 0, 'salesCost': 40009000000, 'sharesIssued': 16976763000, 'sharesOutstandingPeDateBs': 0, 'sharesTreasury': 0, 'stockCommon': 50779000000, 'stockPreferred': 0, 'stockPreferredEquity': 0, 'stockPreferredMezzanine': 0, 'stockTreasury': 0, 'symbol': 'AAPL', 'wabso': 17057620000, 'wabsoSplitAdjusted': 17057620000, 'wadso': 17256524000, 'wadsoSplitAdjusted': 17256524000, 'id': 'FUNDAMENTALS', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1601078400000, 'updated': 1608330863000}]
financials = {'symbol': 'AAPL', 'financials': [{'EBITDA': 17477000000, 'accountsPayable': 42296000000, 'capitalSurplus': None, 'cashChange': -2082000000, 'cashFlow': 80674000000, 'cashFlowFinancing': -86820000000, 'changesInInventories': 83000000, 'changesInReceivables': 5370000000, 'commonStock': 50779000000, 'costOfRevenue': 40009000000, 'currency': 'USD', 'currentAssets': 143713000000, 'currentCash': 90943000000, 'currentDebt': 13769000000, 'currentLongTermDebt': 13769000000, 'depreciation': 11056000000, 'dividendsPaid': None, 'ebit': 14775000000, 'exchangeRateEffect': None, 'filingType': '10-K', 'fiscalDate': '2020-09-26', 'fiscalQuarter': 4, 'fiscalYear': 2020, 'goodwill': 0, 'grossProfit': 24689000000, 'incomeTax': 2228000000, 'intangibleAssets': 0, 'interestIncome': 634000000, 'inventory': 4061000000, 'investingActivityOther': None, 'investments': None, 'longTermDebt': 98667000000, 'longTermInvestments': 180175000000, 'minorityInterest': 0, 'netBorrowings': 10229000000, 'netIncome': 12673000000, 'netIncomeBasic': 12673000000, 'netTangibleAssets': 65339000000, 'operatingExpense': 49923000000, 'operatingIncome': 14775000000, 'operatingRevenue': 64698000000, 'otherAssets': 42522000000, 'otherCurrentAssets
000, 'otherIncomeExpenseNet': 0, 'pretaxIncome': 14901000000, 'reportDate': '2020-10-30', 'researchAndDevelopment': 4978000000, 'sellingGeneralAndAdmin': 4936000000, 'symbol': 'AAPL', 'totalRevenue': 64698000000, 'id': 'INCOME', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1601078400000, 'updated': 1608330865000}, {'costOfRevenue': 37005000000, 'currency': 'USD', 'ebit': 13091000000, 'filingType': '10-Q', 'fiscalDate': '2020-06-27', 'fiscalQuarter': 3, 'fiscalYear': 2020, 'grossProfit': 22680000000, 'incomeTax': 1884000000, 'interestIncome': 697000000, 'minorityInterest': 0, 'netIncome': 11253000000, 'netIncomeBasic': 11253000000, 'operatingExpense': 46594000000, 'operatingIncome': 13091000000, 'otherIncomeExpenseNet': 0, 'pretaxIncome': 13137000000, 'reportDate': '2020-07-31', 'researchAndDevelopment': 4758000000, 'sellingGeneralAndAdmin': 4831000000, 'symbol': 'AAPL', 'totalRevenue': 59685000000, 'id': 'INCOME', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1593216000000, 'updated': 1608330865000}, {'costOfRevenue': 35943000000, 'currency': 'USD', 'ebit': 12853000000, 'filingType': '10-Q', 'fiscalDate': '2020-03-28', 'fiscalQuarter': 2, 'fiscalYear': 2020, 'grossProfit': 22370000000, 'incomeTax': 1886000000, 'interestIncome': 757000000, 'minorityInterest': 0, 'netIncome': 11249000000, 'netIncomeBasic': 11249000000, 'operatingExpense': 45460000000, 'operatingIncome': 12853000000, 'otherIncomeExpenseNet': 0, 'pretaxIncome': 13135000000, 'reportDate': '2020-05-01', 'researchAndDevelopment': 4565000000, 'sellingGeneralAndAdmin': 4952000000, 'symbol': 'AAPL', 'totalRevenue': 58313000000, 'id': 'INCOME', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1585353600000, 'updated': 1608330865000}, {'costOfRevenue': 56602000000, 'currency': 'USD', 'ebit': 25569000000, 'filingType': '10-Q', 'fiscalDate': '2019-12-28', 'fiscalQuarter': 1, 'fiscalYear': 2020, 'grossProfit': 35217000000, 'incomeTax': 3682000000, 'interestIncome': 785000000, 'minorityInterest': 0, 'netIncome': 22236000000, 'netIncomeBasic': 22236000000, 'operatingExpense': 66250000000, 'operatingIncome': 25569000000, 'otherIncomeExpenseNet': 0, 'pretaxIncome': 25918000000, 'reportDate': '2020-01-29', 'researchAndDevelopment': 4451000000, 'sellingGeneralAndAdmin': 5197000000, 'symbol': 'AAPL', 'totalRevenue': 91819000000, 'id': 'INCOME', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1577491200000, 'updated': 1608330865000}, {'costOfRevenue': 39727000000, 'currency': 'USD', 'ebit': 15625000000, 'filingType': '10-K', 'fiscalDate': '2019-09-28', 'fiscalQuarter': 4, 'fiscalYear': 2019, 'grossProfit': 24313000000, 'incomeTax': 2441000000, 'interestIncome': 2710000000, 'minorityInterest': 0, 'netIncome': 13686000000, 'netIncomeBasic': 13686000000, 'operatingExpense': 48415000000, 'operatingIncome': 15625000000, 'otherIncomeExpenseNet': 0, 'pretaxIncome': 16127000000, 'reportDate': '2019-10-31', 'researchAndDevelopment': 4110000000, 'sellingGeneralAndAdmin': 4578000000, 'symbol': 'AAPL', 'totalRevenue': 64040000000, 'id': 'INCOME', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1569628800000, 'updated': 1608330865000}, {'costOfRevenue': 33582000000, 'currency': 'USD', 'ebit': 11544000000, 'filingType': '10-Q', 'fiscalDate': '2019-06-29', 'fiscalQuarter': 3, 'fiscalYear': 2019, 'grossProfit': 20227000000, 'incomeTax': 1867000000, 'interestIncome': 866000000, 'minorityInterest': 0, 'netIncome': 10044000000, 'netIncomeBasic': 10044000000, 'operatingExpense': 42265000000, 'operatingIncome': 11544000000, 'otherIncomeExpenseNet': 0, 'pretaxIncome': 11911000000, 'reportDate': '2019-07-31', 'researchAndDevelopment': 4257000000, 'sellingGeneralAndAdmin': 4426000000, 'symbol': 'AAPL', 'totalRevenue': 53809000000, 'id': 'INCOME', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1561766400000, 'updated': 1608330865000}, {'costOfRevenue': 36194000000, 'currency': 'USD', 'ebit': 13415000000, 'filingType': '10-Q', 'fiscalDate': '2019-03-30', 'fiscalQuarter': 2, 'fiscalYear': 2019, 'grossProfit': 21821000000, 'incomeTax': 2232000000, 'interestIncome': 0, 'minorityInterest': 0, 'netIncome': 11561000000, 'netIncomeBasic': 11561000000, 'operatingExpense': 44600000000, 'operatingIncome': 13415000000, 'otherIncomeExpenseNet': 0, 'pretaxIncome': 13793000000, 'reportDate': '2019-05-01', 'researchAndDevelopment': 3948000000, 'sellingGeneralAndAdmin': 4458000000, 'symbol': 'AAPL', 'totalRevenue': 58015000000, 'id': 'INCOME', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1553904000000, 'updated': 1608330865000}, {'costOfRevenue': 52279000000, 'currency': 'USD', 'ebit': 23346000000, 'filingType': '10-Q', 'fiscalDate': '2018-12-29', 'fiscalQuarter': 1, 'fiscalYear': 2019, 'grossProfit': 32031000000, 'incomeTax': 3941000000, 'interestIncome': 0, 'minorityInterest': 0, 'netIncome': 19965000000, 'netIncomeBasic': 19965000000, 'operatingExpense': 60964000000, 'operatingIncome': 23346000000, 'otherIncomeExpenseNet': 0, 'pretaxIncome': 23906000000, 'reportDate': '2019-01-30', 'researchAndDevelopment': 3902000000, 'sellingGeneralAndAdmin': 4783000000, 'symbol': 'AAPL', 'totalRevenue': 84310000000, 'id': 'INCOME', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1546041600000, 'updated': 1608330865000}, {'costOfRevenue': 38816000000, 'currency': 'USD', 'ebit': 16118000000, 'filingType': '10-K', 'fiscalDate': '2018-09-29', 'fiscalQuarter': 4, 'fiscalYear': 2018, 'grossProfit': 24084000000, 'incomeTax': 2296000000, 'interestIncome': 3240000000, 'minorityInterest': 0, 'netIncome': 14125000000, 'netIncomeBasic': 14125000000, 'operatingExpense': 46782000000, 'operatingIncome': 16118000000, 'otherIncomeExpenseNet': 0, 'pretaxIncome': 16421000000, 'reportDate': '2018-11-05', 'researchAndDevelopment': 3750000000, 'sellingGeneralAndAdmin': 4216000000, 'symbol': 'AAPL', 'totalRevenue': 62900000000, 'id': 'INCOME', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1538179200000, 'updated': 1608330865000}, {'costOfRevenue': 32844000000, 'currency': 'USD', 'ebit': 12612000000, 'filingType': '10-Q', 'fiscalDate': '2018-06-30', 'fiscalQuarter': 3, 'fiscalYear': 2018, 'grossProfit': 20421000000, 'incomeTax': 1765000000, 'interestIncome': 0, 'minorityInterest': 0, 'netIncome': 11519000000, 'netIncomeBasic': 11519000000, 'operatingExpense': 40653000000, 'operatingIncome': 12612000000, 'otherIncomeExpenseNet': 0, 'pretaxIncome': 13284000000, 'reportDate': '2018-08-01', 'researchAndDevelopment': 3701000000, 'sellingGeneralAndAdmin': 4108000000, 'symbol': 'AAPL', 'totalRevenue': 53265000000, 'id': 'INCOME', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1530316800000, 'updated': 1608330865000}, {'costOfRevenue': 37715000000, 'currency': 'USD', 'ebit': 15894000000, 'filingType': '10-Q', 'fiscalDate': '2018-03-31', 'fiscalQuarter': 2, 'fiscalYear': 2018, 'grossProfit': 23422000000, 'incomeTax': 2346000000, 'interestIncome': 0, 'minorityInterest': 0, 'netIncome': 13822000000, 'netIncomeBasic': 13822000000, 'operatingExpense': 45243000000, 'operatingIncome': 15894000000, 'otherIncomeExpenseNet': 0, 'pretaxIncome': 16168000000, 'reportDate': '2018-05-02', 'researchAndDevelopment': 3378000000, 'sellingGeneralAndAdmin': 4150000000, 'symbol': 'AAPL', 'totalRevenue': 61137000000, 'id': 'INCOME', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1522454400000, 'updated': 1608330865000}, {'costOfRevenue': 54381000000, 'currency': 'USD', 'ebit': 26274000000, 'filingType': '10-Q', 'fiscalDate': '2017-12-30', 'fiscalQuarter': 1, 'fiscalYear': 2018, 'grossProfit': 33912000000, 'incomeTax': 6965000000, 'interestIncome': 0, 'minorityInterest': 0, 'netIncome': 20065000000, 'netIncomeBasic': 20065000000, 'operatingExpense': 62019000000, 'operatingIncome': 26274000000, 'otherIncomeExpenseNet': 0, 'pretaxIncome': 27030000000, 'reportDate': '2018-02-02', 'researchAndDevelopment': 3407000000, 'sellingGeneralAndAdmin': 4231000000, 'symbol': 'AAPL', 'totalRevenue': 88293000000, 'id': 'INCOME', 'key': 'AAPL', 'subkey': 'quarterly', 'date': 1514592000000, 'updated': 1608330865000}]}

# %%
import pandas as pd

# %%
cashflow_df = pd.DataFrame(cashflow['cashflow'])
cashflow_df.head().T
# Out:
#                                      0              1              2  \
# capitalExpenditures        -7309000000    -5525000000    -3960000000
# cashChange                 -2082000000    -1026000000   -13111000000
# cashFlow                   80674000000    60098000000    43827000000
# cashFlowFinancing         -86820000000   -65463000000   -46347000000
# changesInInventories          83000000      644000000     -763000000
# changesInReceivables        5370000000     1398000000    -9269000000
# currency                           USD            USD            USD
# depreciation               11056000000     8354000000     5602000000
# dividendsPaid                     None           None           None
# exchangeRateEffect                None           None           None
# filingType                        10-K           10-Q           10-Q
# fiscalDate                  2020-09-26     2020-06-27     2020-03-28
# fiscalQuarter                        4              3              2
# ...

# %%
balance_sheet_df = pd.DataFrame(balance_sheet['balancesheet'])
balance_sheet_df.head().T
# Out:
#                                      0              1              2  \
# accountsPayable            42296000000    35325000000    32421000000
# capitalSurplus                    None           None           None
# commonStock                50779000000    48696000000    48032000000
# currency                           USD            USD            USD
# currentAssets             143713000000   140065000000   143753000000
# currentCash                90943000000    93025000000    94051000000
# currentLongTermDebt        13769000000    18675000000    20421000000
# filingType                        10-K           10-Q           10-Q
# fiscalDate                  2020-09-26     2020-06-27     2020-03-28
# fiscalQuarter                        4              3              2
# fiscalYear                        2020           2020           2020
# goodwill                             0              0              0
# intangibleAssets                     0              0              0
# ...

# %%
income_statement_df = pd.DataFrame(income_statement['income'])
income_statement_df.head().T
# Out:
#                                     0              1              2  \
# costOfRevenue             40009000000    37005000000    35943000000
# currency                          USD            USD            USD
# ebit                      14775000000    13091000000    12853000000
# filingType                       10-K           10-Q           10-Q
# fiscalDate                 2020-09-26     2020-06-27     2020-03-28
# fiscalQuarter                       4              3              2
# fiscalYear                       2020           2020           2020
# grossProfit               24689000000    22680000000    22370000000
# incomeTax                  2228000000     1884000000     1886000000
# interestIncome              634000000      697000000      757000000
# minorityInterest                    0              0              0
# netIncome                 12673000000    11253000000    11249000000
# netIncomeBasic            12673000000    11253000000    11249000000
# ...

# %%
income_statement_df.loc[0,"netIncome"]
# Out:
# 12673000000

# %%
balance_sheet_df.loc[0,"commonStock"]
# Out:
# 50779000000

# %%
cashflow_df.loc[0,"dividendsPaid"]

# %%
(income_statement_df.loc[0,"netIncome"]) / balance_sheet_df.loc[0,"commonStock"]
# Out:
# 0.24957167332952598

# %%
df = income_statement_df[["fiscalYear", "fiscalDate", "fiscalQuarter", "netIncome"]].merge(
    cashflow_df[["fiscalYear", "fiscalDate", "fiscalQuarter", "dividendsPaid"]]).merge(balance_sheet_df[["fiscalYear", "fiscalDate", "fiscalQuarter", "commonStock"]]).fillna(0)
df['earnings_per_share'] = (df["netIncome"] - df["dividendsPaid"]) / df["commonStock"]
df["fiscalDate"] = pd.to_datetime(df['fiscalDate'])
df.sort_values("fiscalDate", ascending=True, inplace=True)

# %%
df.set_index(["fiscalYear", "fiscalDate"], inplace=True)

# %%
def earnings_per_share_percentage_change(x):
    old = x.values[0]
    new = x.values[1]
    percent_change = (new - old) / old
    return percent_change

# %%
df.groupby("fiscalQuarter").rolling(2).apply(earnings_per_share_percentage_change).sort_index(level=2)
# Out:
#                                      fiscalQuarter  netIncome  dividendsPaid  \
# fiscalQuarter fiscalYear fiscalDate
# 1             2018       2017-12-30            NaN        NaN            NaN
# 2             2018       2018-03-31            NaN        NaN            NaN
# 3             2018       2018-06-30            NaN        NaN            NaN
# 4             2018       2018-09-29            NaN        NaN            NaN
# 1             2019       2018-12-29            0.0  -0.004984            NaN
# 2             2019       2019-03-30            0.0  -0.163580            NaN
# 3             2019       2019-06-29            0.0  -0.128049            NaN
# 4             2019       2019-09-28            0.0  -0.031080            NaN
# 1             2020       2019-12-28            0.0   0.113749            NaN
# 2             2020       2020-03-28            0.0  -0.026987            NaN
# 3             2020       2020-06-27            0.0   0.120370            NaN
# ...

# %%
(income_statement_df["netIncome"] - cashflow_df["dividendsPaid"].fillna(0)) / balance_sheet_df["commonStock"]
# Out:
# 0     0.249572
# 1     0.231087
# 2     0.234198
# 3     0.483686
# 4     0.302962
# 5     0.231583
# 6     0.270111
# 7     0.487308
# 8     0.351359
# 9     0.298234
# 10    0.363316
# 11    0.550525
# dtype: float64

# %%
income_statement_df.loc[0,"]
# Out:
# costOfRevenue               40009000000
# currency                            USD
# ebit                        14775000000
# filingType                         10-K
# fiscalDate                   2020-09-26
# fiscalQuarter                         4
# fiscalYear                         2020
# grossProfit                 24689000000
# incomeTax                    2228000000
# interestIncome                634000000
# minorityInterest                      0
# netIncome                   12673000000
# netIncomeBasic              12673000000
# operatingExpense            49923000000
# operatingIncome             14775000000
# otherIncomeExpenseNet                 0
# pretaxIncome                14901000000
# reportDate                   2020-10-30
# researchAndDevelopment       4978000000
# sellingGeneralAndAdmin       4936000000
# symbol                             AAPL
# totalRevenue                64698000000
# id                               INCOME
# ...
